# %% [markdown]
# <a href="https://colab.research.google.com/github/vadimmatytsin/MMVSU1/blob/main/%D0%9B%D0%B0%D0%B12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лаба 2

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

x = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
y = [3169959, 3150039, 3131928, 3140885, 3165924, 3176398, 3184289, 3212536, 3226093, 3218356, 3234252, 3251484, 3269862, 3281655, 3288337, 3293830, 3306698, 3330607, 3351694, 3378795, 3405265, 3459438, 3510683, 3546345, 3581263, 3615485, 3660030, 3692400, 3723969]

plt.plot(x, y)
plt.grid(True)
plt.title('Численность населения г.Тюмень', fontsize=13)
# Out:
# Text(0.5, 1.0, 'Численность населения г.Тюмень')

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def dydt(x,t):
  k = 0.0044
  return k*x
t = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
solve = odeint(dydt, 3169959, t=t)
solve = solve.flatten()
# %matplotlib inline 


v = [3169959, 3150039, 3131928, 3140885, 3165924, 3176398, 3184289, 3212536, 3226093, 3218356, 3234252, 3251484, 3269862, 3281655, 3288337, 3293830, 3306698, 3330607, 3351694, 3378795, 3405265, 3459438, 3510683, 3546345, 3581263, 3615485, 3660030, 3692400, 3723969]


plt.plot(t, solve, label = r"x′=kx")
plt.plot(t, v, label = r"Население Тюмени") 
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
a=-99000
b=1
def dydt(x,t):
  return k(x)*x*0.00455
def k(x):
  return a/x+b
t = [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
solve = odeint(dydt, 3169959, t=t)
solve = solve.flatten()
# %matplotlib inline 

v = [3169959, 3150039, 3131928, 3140885, 3165924, 3176398, 3184289, 3212536, 3226093, 3218356, 3234252, 3251484, 3269862, 3281655, 3288337, 3293830, 3306698, 3330607, 3351694, 3378795, 3405265, 3459438, 3510683, 3546345, 3581263, 3615485, 3660030, 3692400, 3723969]

plt.plot(t, solve, label = r"x'=k(x)*x")
plt.plot(t, v, label = r"Население Казани")
plt.grid(True)
plt.legend()
plt.show()
