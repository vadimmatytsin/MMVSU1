# %% [markdown]
# <a href="https://colab.research.google.com/github/vadimmatytsin/MMVSU1/blob/main/%D0%9B%D0%B0%D0%B13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import odeint
url = 'https://raw.githubusercontent.com/vadimmatytsin/MMVSU1/main/Population.csv'
df = pd.read_csv(url)
print(df)
Years = np.array(df['Years'])
Population = np.array(df['Population'])
def dydt(Years,Population):
  k = 0.0044
  return k*Years

plt.plot(Years, Population)
plt.grid(True)
plt.title('Численность населения г. Тюмень', fontsize=13)
# Out:
#     Years  Population
# 0    1700        2000
# 1    1763        6600
# 2    1800        8300
# 3    1869       13800
# 4    1897       29500
# 5    1912       32200
# 6    1923       42400
# 7    1939       79000
# 8    1959      150000
# 9    1970      269000
# 10   1979      358900
# 11   1989      475600
# 12   1998      501400
# 13   2002      519700
# 14   2007      549900
# 15   2010      581907
# 16   2021      847488
# Text(0.5, 1.0, 'Численность населения г. Тюмень')
